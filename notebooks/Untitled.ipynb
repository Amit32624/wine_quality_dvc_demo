# %%
import os
import pandas as pd

# %%
df = pd.read_csv("../data_given/winequality.csv")

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'TARGET'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# TARGET                1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# TARGET                 6.00000   6.000000    8.00000

# %%
overview = df.describe()

# %%
overview.loc[["min","max"]].to_json("schema_in.json")

# %%
class NotInRange(Exception):
    def __init__(self,inpput__,message="Value no

# %%
pwd
# Out:
# 'F:\\my_projects\\wine_ml\\notebooks'

# %%
from src.get_data import read_params
import argparse
import mlflow
from mlflow.tracking import MlflowClient
from pprint import pprint
import joblib
import os

os.chdir("F:\\my_projects\\wine_ml\\notebooks")
def log_production_model(config_path):
    config = read_params(config_path)

    mlflow_config = config["mlflow_config"]

    model_name = mlflow_config["registered_model_name"]

    remote_server_uri = mlflow_config["remote_server_uri"]

    mlflow.set_registry_uri(remote_server_uri)
    
    runs = mlflow.search_runs(experiment_ids = 1)
    lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
    lowest_run_id = runs[runs["metrics.mae"] == lowest]["run_id"][0]

    client =MlflowClient()
    for mv in client.search_model_versions(f"name ='{model_name}'"):
        mv = dict(mv)

        if mv["run_id"] == lowest_run_id:
            current_version = mv["version"]
            # logged_model = mv["source"]
            print(mv,indent=4)
            client.transition_model_version_stage(
                name =model_name,
                version =current_version,
                stage="Production")

        else:
            current_version = mv["version"]
            print(mv,indent=4)
            client.transition_model_version_stage(
                name =model_name,
                version =current_version,
                stage="Staging")
            
log_production_model("../params.yaml")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5f37a74e6f05> in <module>
#      44                 stage="Staging")
#      45
# ---> 46 log_production_model("../params.yaml")
#
# <ipython-input-5-5f37a74e6f05> in log_production_model(config_path)
#      19     mlflow.set_registry_uri(remote_server_uri)
#      20
# ---> 21     runs = mlflow.search_runs(experiment_ids = 1)
#      22     lowest = runs["metrics.mae"].sort_values(ascending=True)[0]
#      23     lowest_run_id = runs[runs["metrics.mae"] == lowest]["run_id"][0]
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\tracking\fluent.py in search_runs(experiment_ids, filter_string, run_view_type, max_results, order_by, output_format)
#    1058         )
#    1059
# -> 1060     runs = _paginate(pagination_wrapper_func, NUM_RUNS_PER_PAGE_PANDAS, max_results)
#    1061
#    1062     if output_format == "list":
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\tracking\fluent.py in _paginate(paginated_fn, max_results_per_page, max_results)
#    1229             page_results = paginated_fn(num_to_get, next_page_token)
#    1230         else:
# -> 1231             page_results = paginated_fn(max_results_per_page, next_page_token)
#    1232         all_results.extend(page_results)
#    1233         if hasattr(page_results, "token") and page_results.token:
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\tracking\fluent.py in pagination_wrapper_func(number_to_get, next_page_token)
#    1054     # full thing is a mess
#    1055     def pagination_wrapper_func(number_to_get, next_page_token):
# -> 1056         return MlflowClient().search_runs(
#    1057             experiment_ids, filter_string, run_view_type, number_to_get, order_by, next_page_token,
#    1058         )
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\tracking\client.py in search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#    1584             tags: {'s.release': '1.1.0-RC'}
#    1585         """
# -> 1586         return self._tracking_client.search_runs(
#    1587             experiment_ids, filter_string, run_view_type, max_results, order_by, page_token
#    1588         )
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\tracking\_tracking_service\client.py in search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#     415         if isinstance(experiment_ids, int) or is_string_type(experiment_ids):
#     416             experiment_ids = [experiment_ids]
# --> 417         return self.store.search_runs(
#     418             experiment_ids=experiment_ids,
#     419             filter_string=filter_string,
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\store\tracking\abstract_store.py in search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#     239             meaningful in such cases.
#     240         """
# --> 241         runs, token = self._search_runs(
#     242             experiment_ids, filter_string, run_view_type, max_results, order_by, page_token
#     243         )
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\store\tracking\file_store.py in _search_runs(self, experiment_ids, filter_string, run_view_type, max_results, order_by, page_token)
#     756         runs = []
#     757         for experiment_id in experiment_ids:
# --> 758             run_infos = self._list_run_infos(experiment_id, run_view_type)
#     759             runs.extend(self._get_run_from_info(r) for r in run_infos)
#     760         filtered = SearchUtils.filter(runs, filter_string)
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\store\tracking\file_store.py in _list_run_infos(self, experiment_id, view_type)
#     704     def _list_run_infos(self, experiment_id, view_type):
#     705         self._check_root_dir()
# --> 706         if not self._has_experiment(experiment_id):
#     707             return []
#     708         experiment_dir = self._get_experiment_path(experiment_id, assert_exists=True)
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\store\tracking\file_store.py in _has_experiment(self, experiment_id)
#     323
#     324     def _has_experiment(self, experiment_id):
# --> 325         return self._get_experiment_path(experiment_id) is not None
#     326
#     327     def _get_experiment(self, experiment_id, view_type=ViewType.ALL):
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\store\tracking\file_store.py in _get_experiment_path(self, experiment_id, view_type, assert_exists)
#     163             parents.append(self.trash_folder)
#     164         for parent in parents:
# --> 165             exp_list = find(parent, experiment_id, full_path=True)
#     166             if len(exp_list) > 0:
#     167                 return exp_list[0]
#
# c:\users\91720\.conda\envs\wineq\lib\site-packages\mlflow\utils\file_utils.py in find(root, name, full_path)
#      93     :return: list of matching files or directories
#      94     """
# ---> 95     path_name = os.path.join(root, name)
#      96     return list_all(root, lambda x: x == path_name, full_path)
#      97
#
# c:\users\91720\.conda\envs\wineq\lib\ntpath.py in join(path, *paths)
#     115         return result_drive + result_path
#     116     except (TypeError, AttributeError, BytesWarning):
# --> 117         genericpath._check_arg_types('join', path, *paths)
#     118         raise
#     119
#
# c:\users\91720\.conda\envs\wineq\lib\genericpath.py in _check_arg_types(funcname, *args)
#     150             hasbytes = True
#     151         else:
# --> 152             raise TypeError(f'{funcname}() argument must be str, bytes, or '
#     153                             f'os.PathLike object, not {s.__class__.__name__!r}') from None
#     154     if hasstr and hasbytes:
#
# TypeError: join() argument must be str, bytes, or os.PathLike object, not 'int'
